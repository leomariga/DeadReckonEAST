# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import *



df = pd.read_csv('aaaa.txt', sep='\t', header=0, skiprows = [1])
df['ZGPS'] = df['ZGPS']- df['ZGPS'][0]
df['PosX'] = -df['PosX']
df['Alvo_X'] = -df['Alvo_X']

print(list(df.columns.values))
# Out:
# ['Tempo', 'Alt_relativa', 'VCAS', 'VelocidadeGPS', 'DAlvo', 'Dist_aviao_alvo', 'Dist_carga_alvo', 'LancamentoAutomaticoPlanador', 'LancamentoAutomaticoCarga', 'altitudeLiberaCarga', 'altitudeLiberaPlanadores', 'Erro_Alinhamento', 'PosX', 'PosY', 'PosX_carga', 'PosY_carga', 'Alvo_X', 'Alvo_Y', 'XGPS', 'YGPS', 'ZGPS', 'MagHead', 'NZ', 'Gyx', 'Gyy', 'Gyz', 'NX', 'NY', 'MagX', 'MagY', 'MagZ', 'Pressao', 'Temperatura', 'Latitude', 'Longitude', 'HeadGPS', 'VelocidadeGPS.1', 'TemGPS', 'LatitudeHome', 'LongitudeHome', 'HP', 'SatelitesUsados', 'temTempo', 'Aviao_Alvo', 'Unnamed: 44']

# %%
df['LongitudeHome']
# Out:
# 0     -82.025652
# 1     -82.025652
# 2     -82.025652
# 3     -82.025652
# 4     -82.025652
#          ...
# 473   -82.025652
# 474   -82.025652
# 475   -82.025652
# 476   -82.025652
# 477   -82.025652
# Name: LongitudeHome, Length: 478, dtype: float64

# %%
ax = plt.gca()
df.plot(kind='line',x='XGPS',y='YGPS',ax=ax)

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='VelocidadeGPS',ax=ax)
df.plot(kind='line',x='Tempo',y='VCAS',ax=ax)

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='Dist_aviao_alvo',ax=ax)
#df.plot(kind='line',x='Tempo',y='Dist_carga_alvo',ax=ax)
df.plot(kind='line',x='Tempo',y='altitudeLiberaPlanadores',ax=ax)

ax.set_ylim(-20, 300)
ax.set_xlim(64360, 64400)
plt.grid()

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='Erro_Alinhamento',ax=ax)
ax.set_xlim(64360, 64400)
ax.set_ylim(-200, 200)
plt.grid()

# %%
ax = plt.gca()
df.plot(kind='line',x='PosX',y='PosY',ax=ax)
df.plot(kind='scatter',x='Alvo_X',y='Alvo_Y',ax=ax)

ax.set_ylim(-250, 150)
ax.set_xlim(-100, 300)
plt.grid()

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='DAlvo',ax=ax)
df.plot(kind='line',x='Tempo',y='Dist_aviao_alvo',ax=ax)
ax.set_ylim(-20, 300)
ax.set_xlim(64340, 64450)
plt.grid()

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='XGPS',ax=ax)
df.plot(kind='line',x='Tempo',y='PosX',ax=ax)
ax.set_ylim(-300, 50)
ax.set_xlim(64340, 64450)
plt.grid()

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='YGPS',ax=ax)
df.plot(kind='line',x='Tempo',y='PosY',ax=ax)
ax.set_ylim(-250, 200)
ax.set_xlim(64340, 64450)
plt.grid()

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='Dist_aviao_alvo',ax=ax)
#df.plot(kind='line',x='Tempo',y='Dist_carga_alvo',ax=ax)
df.plot(kind='line',x='Tempo',y='altitudeLiberaPlanadores',ax=ax)

ax.set_ylim(-20, 100)
ax.set_xlim(64375, 64385)
plt.grid()

# %%
ax = plt.gca()
df.plot(kind='line',x='Tempo',y='Latitude',ax=ax)
#df.plot(kind='line',x='Tempo',y='Dist_carga_alvo',ax=ax)
#df.plot(kind='line',x='Tempo',y='Longitude',ax=ax)

ax.set_xlim(64375, 64385)
plt.grid()
